# %%
import numpy as np
from matplotlib import pyplot as plt
from skimage.io import imread,imshow,imsave
from matplotlib import pyplot as plt
# %matplotlib notebook
import cv2
from skimage.util import random_noise

# %%
orignal_img = imread("C:\\Users\\Abhijeet\\Downloads\\task2.tif")    # Loading Image
print(orignal_img.shape)

plt.figure()
imshow(orignal_img)
plt.show()
plt.xticks([]), plt.yticks([])     # Hiding X and Y tick value
# Out:
# (688, 688)
# <img src="data:image/png;base64,..." width="640">
# (([], []), ([], []))

# %%
# Adding Noise
noisy_img = random_noise(orignal_img, seed=None, clip=True)
plt.figure()
imshow(noisy_img)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Mean Filter
from scipy.signal import convolve2d

# Mean kernel
ksize = 15
kernel = np.ones((ksize,ksize))
kernel /= kernel.sum()

denoised_img = convolve2d(noisy_img, kernel)

plt.figure()
plt.gray()
plt.subplot(1,2,1)
plt.imshow(noisy_img[::5, ::5])
plt.subplot(1,2,2)
plt.imshow(denoised_img[::5,::5])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
    # Median filter
    ksize = 5
    denoised_img_med = np.zeros(noisy_img.shape)
    for y in range(ksize//2, noisy_img.shape[0]-ksize//2):
        for x in range(ksize//2, noisy_img.shape[1]-ksize//2):
            im_out3[y,x] = np.median(noisy_img[y-ksize//2:y+ksize//2+1, x-ksize//2:x+ksize//2+1])



    plt.figure()
    plt.gray()
    plt.subplot(1,2,1)
    plt.imshow(noisy_img)
    plt.subplot(1,2,2)
    plt.imshow(denoised_img_med)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
